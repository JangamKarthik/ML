# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets,linear_model
from sklearn.metrics import mean_squared_error

# %%
diabetes = datasets.load_diabetes()
diabetes_X = diabetes.data[:, np.newaxis, 2]

# %%
diabetes_X_train = diabetes_X[:-100]
diabetes_X_test = diabetes_X[-100:]
diabetes_Y_train = diabetes.target[:-100]
diabetes_Y_test = diabetes.target[-100:]

# %%
model = linear_model.LinearRegression()
model.fit(diabetes_X_train,diabetes_Y_train)
diabetes_Y_predict = model.predict(diabetes_X_test)

# %%
print("mean squared error is: ",mean_squared_error(diabetes_Y_test,diabetes_Y_predict))
print("weights: ",model.coef_)
print("the intercept is: ",model.intercept_)
# Out:
# mean squared error is:  3752.769434735645
# weights:  [953.3606272]
# the intercept is:  152.27671846254782

# %%
plt.scatter(diabetes_X_test,diabetes_Y_test)
plt.show()

# %%
plt.scatter(diabetes_X_train,diabetes_Y_train,color="black")
plt.scatter(diabetes_X_test,diabetes_Y_test,color="red")
plt.plot(diabetes_X_test,diabetes_Y_predict,color = "blue")
plt.show()

# %%
print("the black dots are training data plots")
print("the red dots are testing data plots")
# Out:
# the black dots are training data plots
# the red dots are testing data plots
